# %%
def subtract(a,b):
    return a-b

# %%
print(subtract(5,3))

# %%
print(subtract(7,3))

# %%
print(subtract(10,3))

# %%
def distance_from_zero(x):
    return subtract(x, 0)

# %%
print(distance_from_zero(5))
